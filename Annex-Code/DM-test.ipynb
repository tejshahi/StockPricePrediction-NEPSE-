# %%
from dm_test import dm_test

# %%
import pandas as pd

# %%
gru_only=pd.read_csv('GRU-Only-Result.csv')

# %%
lstm_only=pd.read_csv('LSTM-Only-Result.csv')

# %%
gru_all=pd.read_csv('GRU-all-Result.csv')

# %%
lstm_all=pd.read_csv('LSTM-all-Result.csv')

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(15,6), dpi=600)
pyplot.plot(gru_only['Actual'], label='Actual Price')
pyplot.plot(gru_only['Predicted'], label='Predicted Price')
pyplot.legend()
pyplot.xlabel('Date')
pyplot.ylabel("Price")
pyplot.grid(True)
pyplot.show()

# %%
def DM_test(df1,df2):
    actual=df1['Actual']
    first=df1['Predicted']
    second=df2['Predicted']
    actual_lst=np.array(actual)
    pred1_lst=np.array(first)
    pred2_lst=np.array(second)
    rtMSE=dm_test(actual_lst,pred1_lst,pred2_lst, h=1,crit='MSE')
    rtMAE=dm_test(actual_lst,pred1_lst, pred2_lst,h=1,crit='MAD')
    print("MSE value", rtMSE)
    print("MAE value", rtMAE)

# %%
import numpy as np
print("DM_Value for GRU-only and GRU-ALL")
DM_test(gru_only,gru_all)
# Out:
# DM_Value for GRU-only and GRU-ALL
# MSE value dm_return(DM=1.5195355824577608, p_value=0.12923784829117543)
# MAE value dm_return(DM=2.087493874798963, p_value=0.037331589758487424)

# %%
print("DM value for LSTM-only and LSTM-ALl")
DM_test(lstm_only,lstm_all)
# Out:
# DM value for LSTM-only and LSTM-ALl
# MSE value dm_return(DM=3.5650066303057018, p_value=0.00039752848916006794)
# MAE value dm_return(DM=3.5977508632980344, p_value=0.0003517662563158589)

# %%
print("DM value for LSTM-only and GRU-All")
DM_test(lstm_only,gru_all)
# Out:
# DM value for LSTM-only and GRU-All
# MSE value dm_return(DM=3.7149980289424107, p_value=0.00022529024859026605)
# MAE value dm_return(DM=2.5204722605017267, p_value=0.012019062305361431)

# %%
print("DM value for GRU-only and LSTm ALL")
DM_test(gru_only,lstm_all)
# Out:
# DM value for GRU-only and LSTm ALL
# MSE value dm_return(DM=1.7934023267736086, p_value=0.07349181567259944)
# MAE value dm_return(DM=3.5464224495647234, p_value=0.00042592472232806395)

# %%
print("DM value for GRU-All and LSTM_only")
DM_test(gru_all,lstm_only)
# Out:
# DM value for GRU-All and LSTM_only
# MSE value dm_return(DM=-3.7149980289424107, p_value=0.00022529024859026605)
# MAE value dm_return(DM=-2.5204722605017267, p_value=0.012019062305361431)

# %%
print("DM_value for GRU-Only and LSTM only")
DM_test(gru_only,lstm_only)
# Out:
# DM_value for GRU-Only and LSTM only
# MSE value dm_return(DM=-2.981331633065705, p_value=0.003004964297614518)
# MAE value dm_return(DM=-1.0464358004856367, p_value=0.2958479102704396)

# %%
print("DM_Value for LSTM-All and GRU-ALL")
DM_test(gru_all,lstm_all)
# Out:
# DM_Value for LSTM-All and GRU-ALL
# MSE value dm_return(DM=0.958295074907976, p_value=0.3383610370169018)
# MAE value dm_return(DM=3.1815134399558596, p_value=0.001552917895672879)

# %%
actual.head()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
plt.plot('Actual', data=df,marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('Predicted', data=df2,marker='+', markerfacecolor='red', markersize=12, color='red', linewidth=4)
plt.show()

# %%
rtMSE=dm_test(actual_lst,pred1_lst,pred2_lst, h=7,crit='MSE')
rtMAE=dm_test(actual_lst,pred1_lst, pred2_lst,h=7,crit='MAD')

# %%
print(rtMSE)
print(rtMAE)
# Out:
# dm_return(DM=0.22846254989218553, p_value=0.8195212623220055)
# dm_return(DM=0.7943573655838966, p_value=0.42793369644046964)
